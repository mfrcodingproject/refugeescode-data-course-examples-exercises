# %% [markdown]
# # EDA Part 2 — Exercises: Histograms, Boxplots, Pairplots and Heatmaps
#
# **Module 9: Exploratory Data Analysis**
#
# ## General instructions
#
# - For each exercise, **read the business question first** before writing any code.
# - The goal is not to make the chart — it is to **answer the question** with the chart.
# - Each exercise has a `# Observations:` block where you should write your findings as comments.
# - We will use the **Superstore** dataset throughout all exercises.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='whitegrid')
pd.set_option('display.max_columns', None)

# Load the dataset ### WARNING: CHANGE THE PATH TO YOUR OWN
from pathlib import Path
df = pd.read_csv('content/5-Data_Visualization_&_Storytelling/3-Visualization-best-practices/Superstore.csv', encoding='latin1')
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date']  = pd.to_datetime(df['Ship Date'])

print(f'Shape: {df.shape}')
df.head(3)

# %% [markdown]
# ---
# ## Block 1 — Histograms
#
# ### Exercise 1.1
# **Business question:** The sales team wants to know how profit (`Profit`) is distributed across transactions. Are most sales profitable? Are there many losses?
#
# Create a histogram of `Profit` with 60 bins. Add vertical lines for the **mean** (red) and the **median** (orange) with their values in the legend.

# %%
# Exercise 1.1 — Profit histogram with mean and median

# Your code here

# %%
# Observations (write your findings here as comments):
# - Is the distribution skewed? In which direction?
# - Are the mean and median close or far apart? What does that tell you?
# - What percentage of transactions have negative profit?

# %% [markdown]
# ### Exercise 1.2
# **Business question:** Is the distribution of the applied discount (`Discount`) similar across all categories, or are there categories where discounts are higher?
#
# Create **3 side-by-side histograms** (one per category) showing the distribution of `Discount`. Use `sharey=True` so the Y axes are comparable.

# %%
# Exercise 1.2 — Discount histograms by Category

# Your code here

# %%
# Observations:
# - Is there a category where high discounts (>0.4) are more frequent?
# - Does the discount distribution look uniform or does it have specific peaks?

# %% [markdown]
# ### Exercise 1.3 — Intermediate level
# **Business question:** Does the sales (`Sales`) distribution vary significantly across regions?
#
# Create an overlapping histogram with `alpha=0.5` for all 4 regions in a single chart. Add a legend.
#
# *Hint: iterate over the unique regions and use `ax.hist()` in each iteration.*

# %%
# Exercise 1.3 — Overlapping histogram by Region

# Your code here

# %%
# Observations:
# - Do all 4 regions have similar distributions?
# - Does any region stand out for having higher or more dispersed sales?
# - Is the overlapping chart easy to read? When would subplots be better?

# %% [markdown]
# ---
# ## Block 2 — Boxplots
#
# ### Exercise 2.1
# **Business question:** The management team wants to know if there are profitability differences between the three customer segments (`Segment`: Consumer, Corporate, Home Office).
#
# Create a boxplot of `Profit` by `Segment`. Add a dashed red line at y=0 to mark the break-even point.

# %%
# Exercise 2.1 — Profit boxplot by Segment

# Your code here

# %%
# Observations:
# - Which segment has the highest median?
# - Which segment has the most variability (largest box)?
# - Are there negative outliers? In which segment?

# %% [markdown]
# ### Exercise 2.2
# **Business question:** Does the profitability problem in Furniture repeat equally across all regions, or is there a region where it is especially severe?
#
# Create a boxplot of `Profit` **for the Furniture category only**, with `Region` on the X axis. Apply a zoom between -400 and 400. Add the break-even line.

# %%
# Exercise 2.2 — Profit boxplot for Furniture by Region

furniture = df[df['Category'] == 'Furniture']

# Your code here

# %%
# Observations:
# - Is there a region where Furniture has a clearly negative median?
# - Which region seems to manage Furniture profitability best?
# - What hypothesis would you generate to investigate next?

# %% [markdown]
# ### Exercise 2.3 — Intermediate level
# **Business question:** Does the discount level vary across categories AND across segments at the same time?
#
# Create a boxplot of `Discount` with `Category` on the X axis and `hue='Segment'`. Interpret the result.

# %%
# Exercise 2.3 — Multidimensional boxplot: Discount by Category and Segment

# Your code here

# %%
# Observations:
# - Is there a Category + Segment combination with systematically high discounts?
# - Do discounts appear to be a segment-specific policy, or the same for everyone?

# %% [markdown]
# ---
# ## Block 3 — Pairplot
#
# ### Exercise 3.1
# **Business question:** We want to get a first overview of how the numerical variables in the dataset relate to each other.
#
# Create a pairplot with columns `['Sales', 'Quantity', 'Discount', 'Profit']` using a 600-row sample. Use `diag_kind='kde'` and `alpha=0.4`.

# %%
# Exercise 3.1 — Basic pairplot

cols = ['Sales', 'Quantity', 'Discount', 'Profit']
df_sample = df[cols].sample(600, random_state=42)

# Your code here

# %%
# Observations — answer these questions by looking at the pairplot:
# - Which pair of variables appears to have the strongest correlation (positive or negative)?
# - Does the Discount vs Profit scatter show a clear pattern?
# - Does any variable have a clearly non-normal distribution (according to the diagonal)?

# %% [markdown]
# ### Exercise 3.2 — Intermediate level
# **Business question:** Are the relationships between numerical variables different depending on the product category?
#
# Repeat the previous pairplot adding `hue='Category'`. Use the same 600-row sample but now include the `Category` column.

# %%
# Exercise 3.2 — Pairplot with hue by Category

cols_cat = ['Sales', 'Quantity', 'Discount', 'Profit', 'Category']
df_sample_cat = df[cols_cat].sample(600, random_state=42)

# Your code here

# %%
# Observations:
# - In the Discount vs Profit scatter, do the three colours separate well?
# - Is there a category with much higher sales than the others (according to the Sales diagonal)?
# - What new hypothesis does this pairplot generate compared to the previous one?

# %% [markdown]
# ---
# ## Block 4 — Correlation Heatmap
#
# ### Exercise 4.1
# **Business question:** What are the statistical relationships between the numerical variables? What correlates most with profit?
#
# Compute the correlation matrix of `['Sales', 'Quantity', 'Discount', 'Profit']` and visualise it as a heatmap with annotations, using the `'coolwarm'` colormap with `vmin=-1, vmax=1`.

# %%
# Exercise 4.1 — Basic correlation heatmap

# Your code here

# %%
# Observations:
# - Which variable has the strongest correlation (in absolute value) with Profit?
# - Is the Sales-Profit correlation positive or negative? Does its magnitude surprise you?
# - Which pair of variables has the correlation closest to 0?

# %% [markdown]
# ### Exercise 4.2 — Intermediate level
# **Business question:** Are the correlations between variables different depending on the category? Does discount have the same effect in Furniture as in Technology?
#
# Compute and visualise **three heatmaps in a row** (one per category), with `fig, axes = plt.subplots(1, 3)`. Each heatmap should show the correlation between `Sales`, `Discount` and `Profit` for that category.

# %%
# Exercise 4.2 — Correlation heatmaps by Category

categories = df['Category'].unique()
cols_corr = ['Sales', 'Discount', 'Profit']

# Your code here

# %%
# Observations:
# - Is the Discount-Profit correlation equally negative across all three categories?
# - Is there a category where Discount and Sales have a different relationship?
# - What conclusion do you draw about the effect of discounts depending on the category?

# %% [markdown]
# ---
# ## Block 5 — Integrated exercise
#
# **Business question:** The sales director suspects that high discounts are destroying profitability in certain sub-categories. They ask you to conduct a full exploratory analysis.
#
# Use the full EDA workflow to answer:
# 1. How is `Discount` distributed? (histogram)
# 2. Are there sub-categories with systematically higher discounts? (boxplot)
# 3. Does `Discount` correlate negatively with `Profit` across sub-categories? (heatmap or scatter)
# 4. Formulate a final hypothesis and the questions you would investigate next.

# %%
# Step 1 — Discount histogram

# Your code here

# %%
# Step 2 — Discount boxplot by Sub-Category
# Hint: use horizontal orientation so the names fit

# Your code here

# %%
# Step 3 — Discount vs Profit scatter with hue='Category'

# Your code here

# %%
# Step 4 — Hypothesis and questions to investigate next
# Write your conclusions here as comments:

# Main hypothesis:
#
# Evidence found:
#
# Questions that I would investigate next:
# 1.
# 2.
# 3.
